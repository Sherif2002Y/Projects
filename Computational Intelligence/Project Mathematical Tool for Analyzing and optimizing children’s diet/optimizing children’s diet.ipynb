# %%
import random

# Define the problem parameters
n_vars = 8
n_bits = 10
objective_coeffs = [0.25, 0.15, 0.20, 0.15, 0.15, 0.25, 0.20, 0.08]
constraints_coeffs = [
    [16, 28, 37, 34, 99, 350.35, 43, 8],
    [267, 115, 332, 405, 558, 445.9, 166, 328],
    [1.14, 0.8, 2.57, 3.88, 2.71, 0.15, 0.13, 0.31],
    [33.44, 7.1, 13.05, 13.7, 2.86, 9.68, 0.91, 1.71],
    [0, 1.3, 0, 12.2, 2.2, 0, 2.2, 1.8],
    [31, 25, 130, 138, 79, 36.75, 11, 20],
    [0.42, 0.11, 0.9, 0.82, 2.03, 0, 0.15, 0.01],
]

constraints_values = [1000, 4700, 8, 56, 30.08, 420, 15]

mutation_rate = 0.1
crossover_rate = 0.8

# %%
# Define the genetic operators
def initialize_population(pop_size):
    population = []
    for i in range(pop_size):
        chromosome = [random.randint(0, 1) for j in range(n_vars*n_bits)]
        population.append(chromosome)
    return population

# %%
# Define the encoding and decoding functions
def decode_chromosome(chromosome):
    vars = []
    for i in range(n_vars):
        var = 0
        for j in range(n_bits):
            var += chromosome[i*n_bits+j] * 2**j
        vars.append(var)
    return vars

# %%
def evaluate_objective(vars):
    return sum([coeff * var for coeff, var in zip(objective_coeffs, vars)])

# %%
def evaluate_constraints(vars):
    results = []
    for i in range(len(constraints_coeffs)):
        constraint_coeffs = constraints_coeffs[i]
        constraint_value = constraints_values[i]
        constraint_sum = sum([coeff * var for coeff, var in zip(constraint_coeffs, vars)])
        if constraint_sum >= constraint_value:
            results.append(constraint_sum - constraint_value)
        else:
            results.append(-1)  # return a negative value if the constraint is violated
    return results

# %%
def mutate(chromosome):
    for i in range(len(chromosome)):
        if random.random() < mutation_rate:
            chromosome[i] = 1 - chromosome[i]
    return chromosome

# %%
def crossover(chromosome1, chromosome2):
    if random.random() < crossover_rate:
        crossover_point = random.randint(1, len(chromosome1) - 1)
        new_chromosome1 = chromosome1[:crossover_point] + chromosome2[crossover_point:]
        new_chromosome2 = chromosome2[:crossover_point] + chromosome1[crossover_point:]
        return new_chromosome1, new_chromosome2
    else:
        return chromosome1, chromosome2

# %%
# Define the main genetic algorithm loop
pop_size = 50
max_gen = 50
for gen in range(max_gen):
   
    population = initialize_population(pop_size)
 
    # Evaluate the fitness of each chromosome
    fitness_values = [evaluate_objective(decode_chromosome(chromosome)) for chromosome in population]

    # Select the parents for reproduction
    total_fitness = sum(fitness_values)
    probabilities = [fitness / total_fitness for fitness in fitness_values]
    parents_indices = random.choices(range(pop_size), weights=probabilities, k=pop_size)

    # Create the offspring population through crossover and mutation
    offspring_population = []
    for i in range(pop_size // 2):
        parent1_index, parent2_index = parents_indices[2*i], parents_indices[2*i+1]
        parent1, parent2 = population[parent1_index], population[parent2_index]
        offspring1, offspring2 = crossover(parent1, parent2)
        offspring1 = mutate(offspring1)
        offspring2 = mutate(offspring2)
        offspring_population.extend([offspring1, offspring2])

    # Evaluate the fitness of the offspring population
    offspring_fitness_values = [evaluate_objective(decode_chromosome(chromosome)) for chromosome in offspring_population]

    # Replace the old population with the new offspring population
    population = offspring_population + population[:pop_size-len(offspring_population)]

    # Print the best solution of the current generation
    best_index = fitness_values.index(max(fitness_values))
    best_solution = decode_chromosome(population[best_index])
    print(f"Generation {gen+1}: Best solution = {best_solution}, Objective value = {max(fitness_values)}")

# Print the final solution

best_index = fitness_values.index(max(fitness_values))
best_chromosome = population[best_index]
best_solution = decode_chromosome(best_chromosome)
print(f"Final solution: {best_solution}, Objective value: {evaluate_objective(best_solution)}")
# Out:
# Generation 1: Best solution = [989, 717, 120, 396, 380, 240, 170, 11], Objective value = 935.1299999999999
# Generation 2: Best solution = [214, 574, 467, 229, 816, 281, 429, 710], Objective value = 1025.36
# Generation 3: Best solution = [644, 784, 592, 351, 142, 319, 123, 720], Objective value = 1150.6
# Generation 4: Best solution = [669, 836, 997, 523, 223, 163, 14, 352], Objective value = 1084.6000000000001
# Generation 5: Best solution = [676, 174, 789, 15, 979, 219, 747, 961], Objective value = 1061.3700000000001
# Generation 6: Best solution = [966, 859, 706, 731, 873, 629, 978, 243], Objective value = 1058.55
# Generation 7: Best solution = [2, 177, 232, 252, 422, 467, 332, 396], Objective value = 1060.54
# Generation 8: Best solution = [752, 764, 705, 252, 808, 117, 815, 940], Objective value = 1010.39
# Generation 9: Best solution = [618, 168, 507, 185, 655, 1003, 582, 711], Objective value = 1111.1100000000001
# Generation 10: Best solution = [686, 153, 55, 891, 762, 921, 625, 309], Objective value = 1188.57
# Generation 11: Best solution = [374, 769, 680, 33, 58, 965, 478, 164], Objective value = 1130.6000000000001
# Generation 12: Best solution = [907, 921, 583, 483, 304, 722, 919, 645], Objective value = 1005.8
# Generation 13: Best solution = [822, 427, 908, 373, 98, 369, 622, 231], Objective value = 1027.1499999999999
# Generation 14: Best solution = [585, 331, 510, 847, 419, 960, 822, 10], Objective value = 1052.46
# Generation 15: Best solution = [358, 191, 741, 203, 317, 637, 956, 652], Objective value = 1061.26
# Generation 16: Best solution = [787, 87, 240, 115, 710, 821, 187, 888], Objective value = 1190.24
# Generation 17: Best solution = [505, 773, 83, 462, 960, 843, 733, 596], Objective value = 1121.5300000000002
# Generation 18: Best solution = [213, 561, 357, 174, 423, 655, 827, 464], Objective value = 1168.06
# Generation 19: Best solution = [572, 68, 180, 34, 113, 186, 464, 165], Objective value = 1007.7700000000001
# Generation 20: Best solution = [71, 694, 853, 305, 478, 574, 636, 9], Objective value = 1058.57
# Generation 21: Best solution = [241, 2, 523, 219, 105, 972, 557, 51], Objective value = 1084.43
# Generation 22: Best solution = [561, 1020, 242, 187, 785, 670, 450, 770], Objective value = 1115.79
# Generation 23: Best solution = [919, 931, 495, 807, 137, 406, 187, 300], Objective value = 1004.5
# Generation 24: Best solution = [388, 579, 221, 92, 212, 218, 960, 838], Objective value = 1106.67
# Generation 25: Best solution = [240, 994, 835, 149, 586, 270, 319, 349], Objective value = 1023.4300000000001
# Generation 26: Best solution = [669, 684, 876, 376, 507, 136, 889, 794], Objective value = 1020.36
# Generation 27: Best solution = [158, 635, 251, 405, 23, 759, 688, 896], Objective value = 1111.46
# Generation 28: Best solution = [208, 3, 618, 651, 901, 861, 668, 655], Objective value = 1089.93
# Generation 29: Best solution = [609, 614, 598, 461, 951, 15, 155, 209], Objective value = 1023.61
# Generation 30: Best solution = [51, 726, 217, 799, 1000, 810, 745, 342], Objective value = 1105.21
# Generation 31: Best solution = [1006, 433, 953, 646, 696, 597, 197, 986], Objective value = 1029.73
# Generation 32: Best solution = [399, 190, 966, 548, 587, 526, 750, 13], Objective value = 1163.5399999999997
# Generation 33: Best solution = [800, 7, 799, 76, 428, 474, 911, 1012], Objective value = 1029.75
# Generation 34: Best solution = [264, 199, 82, 990, 687, 345, 63, 631], Objective value = 1081.13
# Generation 35: Best solution = [508, 254, 852, 522, 640, 669, 203, 88], Objective value = 1107.79
# Generation 36: Best solution = [764, 913, 579, 700, 47, 954, 298, 83], Objective value = 1117.13
# Generation 37: Best solution = [233, 141, 696, 535, 611, 595, 7, 651], Objective value = 1244.5199999999998
# Generation 38: Best solution = [712, 341, 475, 211, 209, 246, 745, 956], Objective value = 1084.7800000000002
# Generation 39: Best solution = [497, 774, 632, 727, 347, 365, 896, 294], Objective value = 1060.47
# Generation 40: Best solution = [487, 884, 347, 28, 1001, 224, 874, 339], Objective value = 1039.35
# Generation 41: Best solution = [772, 840, 142, 528, 340, 325, 320, 332], Objective value = 1127.73
# Generation 42: Best solution = [759, 245, 762, 852, 465, 224, 804, 244], Objective value = 1105.25
# Generation 43: Best solution = [446, 3, 480, 832, 615, 623, 378, 962], Objective value = 1023.07
# Generation 44: Best solution = [630, 808, 973, 41, 723, 843, 683, 241], Objective value = 1195.01
# Generation 45: Best solution = [497, 996, 998, 702, 512, 802, 878, 238], Objective value = 1078.6699999999998
# Generation 46: Best solution = [9, 998, 905, 634, 1005, 612, 871, 450], Objective value = 1087.33
# Generation 47: Best solution = [562, 72, 586, 279, 95, 400, 773, 457], Objective value = 1148.8899999999999
# Generation 48: Best solution = [400, 694, 933, 615, 645, 759, 653, 423], Objective value = 1017.5300000000001
# Generation 49: Best solution = [364, 353, 329, 602, 289, 263, 376, 656], Objective value = 1039.55
# Generation 50: Best solution = [815, 720, 10, 705, 429, 771, 219, 836], Objective value = 969.5799999999999
# Final solution: [815, 720, 10, 705, 429, 771, 219, 836], Objective value: 787.28

# %%
# Define the main genetic algorithm loop
pop_size = 70
max_gen = 70
for gen in range(max_gen):
  
    population = initialize_population(pop_size)
 
    # Evaluate the fitness of each chromosome
    fitness_values = [evaluate_objective(decode_chromosome(chromosome)) for chromosome in population]

    # Select the parents for reproduction
    total_fitness = sum(fitness_values)
    probabilities = [fitness / total_fitness for fitness in fitness_values]
    parents_indices = random.choices(range(pop_size), weights=probabilities, k=pop_size)

    # Create the offspring population through crossover and mutation
    offspring_population = []
    for i in range(pop_size // 2):
        parent1_index, parent2_index = parents_indices[2*i], parents_indices[2*i+1]
        parent1, parent2 = population[parent1_index], population[parent2_index]
        offspring1, offspring2 = crossover(parent1, parent2)
        offspring1 = mutate(offspring1)
        offspring2 = mutate(offspring2)
        offspring_population.extend([offspring1, offspring2])

    # Evaluate the fitness of the offspring population
    offspring_fitness_values = [evaluate_objective(decode_chromosome(chromosome)) for chromosome in offspring_population]

    # Replace the old population with the new offspring population
    population = offspring_population + population[:pop_size-len(offspring_population)]

    # Print the best solution of the current generation
    best_index = fitness_values.index(max(fitness_values))
    best_solution = decode_chromosome(population[best_index])
    print(f"Generation {gen+1}: Best solution = {best_solution}, Objective value = {max(fitness_values)}")

# Print the final solution

best_index = fitness_values.index(max(fitness_values))
best_chromosome = population[best_index]
best_solution = decode_chromosome(best_chromosome)
print(f"Final solution: {best_solution}, Objective value: {evaluate_objective(best_solution)}")



print("################################################")
# Out:
# Generation 1: Best solution = [800, 274, 398, 69, 727, 673, 140, 102], Objective value = 1162.56
# Generation 2: Best solution = [880, 110, 515, 31, 508, 800, 90, 995], Objective value = 1075.19
# Generation 3: Best solution = [675, 969, 958, 350, 285, 788, 975, 668], Objective value = 1054.53
# Generation 4: Best solution = [414, 709, 198, 512, 803, 104, 36, 977], Objective value = 1150.73
# Generation 5: Best solution = [950, 749, 826, 515, 840, 617, 981, 887], Objective value = 1138.3700000000001
# Generation 6: Best solution = [547, 228, 310, 35, 297, 477, 518, 305], Objective value = 1160.14
# Generation 7: Best solution = [1018, 977, 396, 190, 111, 84, 770, 88], Objective value = 1038.68
# Generation 8: Best solution = [37, 1019, 156, 308, 491, 114, 760, 345], Objective value = 1106.94
# Generation 9: Best solution = [97, 1002, 159, 97, 247, 17, 276, 287], Objective value = 1089.04
# Generation 10: Best solution = [161, 298, 25, 596, 56, 886, 701, 385], Objective value = 1002.7
# Generation 11: Best solution = [951, 418, 320, 789, 218, 875, 912, 240], Objective value = 1072.0400000000002
# Generation 12: Best solution = [28, 885, 125, 79, 246, 933, 577, 214], Objective value = 1058.77
# Generation 13: Best solution = [1008, 85, 808, 212, 39, 32, 288, 720], Objective value = 1171.39
# Generation 14: Best solution = [98, 419, 572, 992, 465, 581, 337, 465], Objective value = 1026.54
# Generation 15: Best solution = [434, 713, 190, 254, 639, 286, 55, 488], Objective value = 1058.58
# Generation 16: Best solution = [462, 14, 323, 318, 642, 892, 471, 705], Objective value = 1002.4099999999999
# Generation 17: Best solution = [108, 807, 644, 159, 456, 952, 240, 919], Objective value = 1108.89
# Generation 18: Best solution = [1009, 684, 145, 918, 924, 293, 95, 106], Objective value = 1093.8000000000002
# Generation 19: Best solution = [623, 240, 365, 911, 771, 313, 319, 239], Objective value = 1145.9399999999998
# Generation 20: Best solution = [761, 899, 343, 22, 643, 110, 499, 857], Objective value = 1029.73
# Generation 21: Best solution = [927, 362, 329, 2, 994, 634, 1000, 284], Objective value = 999.57
# Generation 22: Best solution = [712, 416, 313, 957, 617, 658, 447, 925], Objective value = 998.9299999999998
# Generation 23: Best solution = [87, 666, 710, 580, 1, 950, 119, 873], Objective value = 1051.81
# Generation 24: Best solution = [349, 555, 1008, 331, 493, 478, 880, 538], Objective value = 1222.5499999999997
# Generation 25: Best solution = [682, 719, 295, 801, 773, 458, 806, 63], Objective value = 1138.02
# Generation 26: Best solution = [867, 404, 29, 554, 241, 914, 864, 773], Objective value = 1101.46
# Generation 27: Best solution = [250, 324, 639, 751, 153, 554, 864, 259], Objective value = 1124.26
# Generation 28: Best solution = [812, 627, 510, 577, 1004, 662, 963, 877], Objective value = 977.43
# Generation 29: Best solution = [507, 918, 871, 613, 10, 43, 843, 908], Objective value = 1116.3200000000002
# Generation 30: Best solution = [426, 19, 289, 574, 843, 999, 950, 256], Objective value = 1087.3799999999999
# Generation 31: Best solution = [503, 900, 746, 991, 512, 550, 642, 638], Objective value = 1060.06
# Generation 32: Best solution = [367, 960, 814, 894, 517, 616, 371, 362], Objective value = 1123.8500000000001
# Generation 33: Best solution = [479, 409, 684, 76, 941, 651, 649, 780], Objective value = 1077.23
# Generation 34: Best solution = [766, 564, 883, 54, 180, 850, 567, 707], Objective value = 1043.4199999999998
# Generation 35: Best solution = [463, 246, 409, 555, 399, 468, 631, 403], Objective value = 1107.8999999999999
# Generation 36: Best solution = [769, 401, 11, 519, 211, 473, 162, 686], Objective value = 1240.02
# Generation 37: Best solution = [13, 508, 756, 864, 518, 666, 272, 256], Objective value = 1164.83
# Generation 38: Best solution = [884, 635, 938, 761, 558, 866, 682, 282], Objective value = 1092.77
# Generation 39: Best solution = [881, 314, 296, 906, 731, 478, 196, 276], Objective value = 1042.5100000000002
# Generation 40: Best solution = [89, 416, 877, 245, 115, 96, 765, 237], Objective value = 1104.4199999999998
# Generation 41: Best solution = [721, 261, 179, 958, 669, 736, 521, 817], Objective value = 1112.8400000000001
# Generation 42: Best solution = [467, 461, 339, 634, 383, 652, 722, 622], Objective value = 1038.32
# Generation 43: Best solution = [898, 637, 827, 223, 215, 428, 33, 678], Objective value = 1072.1499999999999
# Generation 44: Best solution = [684, 825, 405, 453, 31, 684, 898, 51], Objective value = 1008.21
# Generation 45: Best solution = [913, 208, 972, 428, 931, 1010, 526, 210], Objective value = 1131.24
# Generation 46: Best solution = [570, 494, 181, 516, 29, 380, 495, 29], Objective value = 1039.4399999999998
# Generation 47: Best solution = [555, 377, 742, 598, 731, 912, 298, 317], Objective value = 1060.42
# Generation 48: Best solution = [217, 695, 439, 325, 556, 926, 76, 808], Objective value = 1072.69
# Generation 49: Best solution = [716, 542, 197, 292, 382, 842, 711, 57], Objective value = 1094.74
# Generation 50: Best solution = [595, 666, 910, 466, 260, 934, 519, 117], Objective value = 1125.35
# Generation 51: Best solution = [245, 995, 416, 637, 166, 750, 905, 785], Objective value = 1124.63
# Generation 52: Best solution = [286, 361, 582, 357, 106, 782, 609, 983], Objective value = 1140.15
# Generation 53: Best solution = [847, 942, 503, 709, 198, 430, 30, 202], Objective value = 1174.34
# Generation 54: Best solution = [528, 474, 954, 971, 405, 356, 237, 59], Objective value = 1128.68
# Generation 55: Best solution = [428, 922, 667, 483, 783, 364, 925, 426], Objective value = 1094.69
# Generation 56: Best solution = [3, 461, 811, 156, 244, 247, 282, 138], Objective value = 1087.8899999999999
# Generation 57: Best solution = [293, 446, 953, 686, 258, 285, 378, 1020], Objective value = 1118.39
# Generation 58: Best solution = [361, 786, 675, 881, 289, 432, 753, 499], Objective value = 1037.8
# Generation 59: Best solution = [872, 755, 629, 108, 203, 281, 662, 329], Objective value = 1089.52
# Generation 60: Best solution = [493, 561, 935, 621, 578, 786, 69, 852], Objective value = 1081.96
# Generation 61: Best solution = [625, 196, 511, 600, 925, 975, 736, 135], Objective value = 1106.8
# Generation 62: Best solution = [648, 425, 526, 434, 289, 724, 633, 316], Objective value = 1127.9299999999998
# Generation 63: Best solution = [918, 960, 236, 1002, 698, 654, 864, 14], Objective value = 1160.88
# Generation 64: Best solution = [465, 608, 735, 182, 757, 214, 341, 158], Objective value = 1074.9
# Generation 65: Best solution = [688, 591, 439, 106, 790, 744, 685, 341], Objective value = 1014.07
# Generation 66: Best solution = [641, 359, 470, 846, 262, 594, 233, 515], Objective value = 1004.66
# Generation 67: Best solution = [387, 292, 266, 456, 923, 31, 739, 969], Objective value = 1074.33
# Generation 68: Best solution = [657, 138, 632, 401, 86, 431, 370, 389], Objective value = 1075.91
# Generation 69: Best solution = [677, 737, 787, 544, 77, 235, 319, 277], Objective value = 1089.4999999999998
# Generation 70: Best solution = [610, 315, 650, 231, 531, 984, 750, 626], Objective value = 1117.75
# Final solution: [610, 315, 650, 231, 531, 984, 750, 626], Objective value: 890.13
# ################################################

# %%
################################################################################################
pop_size = 100
max_gen = 100
for gen in range(max_gen):
   
    population = initialize_population(pop_size)
 
    # Evaluate the fitness of each chromosome
    fitness_values = [evaluate_objective(decode_chromosome(chromosome)) for chromosome in population]

    # Select the parents for reproduction
    total_fitness = sum(fitness_values)
    probabilities = [fitness / total_fitness for fitness in fitness_values]
    parents_indices = random.choices(range(pop_size), weights=probabilities, k=pop_size)

    # Create the offspring population through crossover and mutation
    offspring_population = []
    for i in range(pop_size // 2):
        parent1_index, parent2_index = parents_indices[2*i], parents_indices[2*i+1]
        parent1, parent2 = population[parent1_index], population[parent2_index]
        offspring1, offspring2 = crossover(parent1, parent2)
        offspring1 = mutate(offspring1)
        offspring2 = mutate(offspring2)
        offspring_population.extend([offspring1, offspring2])

    # Evaluate the fitness of the offspring population
    offspring_fitness_values = [evaluate_objective(decode_chromosome(chromosome)) for chromosome in offspring_population]

    # Replace the old population with the new offspring population
    population = offspring_population + population[:pop_size-len(offspring_population)]

    # Print the best solution of the current generation
    best_index = fitness_values.index(max(fitness_values))
    best_solution = decode_chromosome(population[best_index])
    print(f"Generation {gen+1}: Best solution = {best_solution}, Objective value = {max(fitness_values)}")

# Print the final solution

best_index = fitness_values.index(max(fitness_values))
best_chromosome = population[best_index]
best_solution = decode_chromosome(best_chromosome)
print(f"Final solution: {best_solution}, Objective value: {evaluate_objective(best_solution)}")

print("################################################")
# Out:
# Generation 1: Best solution = [705, 483, 359, 759, 840, 279, 256, 590], Objective value = 1135.17
# Generation 2: Best solution = [587, 967, 695, 185, 398, 277, 385, 276], Objective value = 1116.06
# Generation 3: Best solution = [318, 393, 886, 884, 582, 431, 917, 646], Objective value = 1077.5700000000002
# Generation 4: Best solution = [546, 910, 766, 502, 630, 145, 335, 948], Objective value = 1033.1499999999999
# Generation 5: Best solution = [988, 636, 503, 7, 1020, 963, 60, 504], Objective value = 1122.73
# Generation 6: Best solution = [369, 430, 621, 715, 819, 487, 941, 701], Objective value = 1220.5700000000002
# Generation 7: Best solution = [439, 812, 918, 433, 282, 997, 867, 339], Objective value = 1105.5800000000002
# Generation 8: Best solution = [36, 936, 369, 633, 806, 155, 323, 544], Objective value = 1171.11
# Generation 9: Best solution = [143, 412, 835, 448, 626, 714, 721, 956], Objective value = 1145.38
# Generation 10: Best solution = [429, 309, 891, 117, 885, 319, 442, 723], Objective value = 1129.18
# Generation 11: Best solution = [290, 311, 456, 278, 51, 285, 215, 191], Objective value = 1171.45
# Generation 12: Best solution = [899, 465, 313, 365, 623, 963, 817, 623], Objective value = 1066.19
# Generation 13: Best solution = [973, 684, 542, 146, 217, 40, 448, 55], Objective value = 1132.56
# Generation 14: Best solution = [427, 617, 497, 314, 48, 973, 256, 444], Objective value = 1123.4399999999998
# Generation 15: Best solution = [987, 179, 83, 377, 958, 7, 432, 156], Objective value = 1107.68
# Generation 16: Best solution = [235, 493, 305, 272, 851, 712, 668, 713], Objective value = 1098.73
# Generation 17: Best solution = [345, 659, 740, 868, 812, 859, 171, 122], Objective value = 1210.89
# Generation 18: Best solution = [473, 335, 194, 678, 658, 474, 20, 758], Objective value = 1096.29
# Generation 19: Best solution = [988, 835, 482, 531, 259, 184, 953, 999], Objective value = 1215.2199999999998
# Generation 20: Best solution = [791, 915, 905, 79, 15, 97, 436, 541], Objective value = 1098.27
# Generation 21: Best solution = [558, 511, 184, 114, 9, 61, 147, 981], Objective value = 1016.52
# Generation 22: Best solution = [264, 367, 428, 614, 455, 1016, 944, 373], Objective value = 1065.36
# Generation 23: Best solution = [706, 950, 500, 982, 11, 951, 895, 363], Objective value = 1116.77
# Generation 24: Best solution = [854, 925, 179, 139, 159, 155, 33, 25], Objective value = 1152.01
# Generation 25: Best solution = [714, 593, 55, 598, 248, 298, 782, 216], Objective value = 1125.3500000000001
# Generation 26: Best solution = [461, 16, 820, 145, 965, 252, 640, 302], Objective value = 1212.37
# Generation 27: Best solution = [243, 521, 421, 815, 743, 602, 756, 395], Objective value = 1000.1400000000001
# Generation 28: Best solution = [450, 933, 841, 873, 451, 787, 9, 964], Objective value = 1100.91
# Generation 29: Best solution = [700, 812, 923, 491, 414, 684, 361, 196], Objective value = 1092.0500000000002
# Generation 30: Best solution = [754, 964, 427, 633, 82, 741, 854, 998], Objective value = 1195.8000000000002
# Generation 31: Best solution = [883, 381, 72, 691, 437, 440, 854, 223], Objective value = 1145.1
# Generation 32: Best solution = [638, 71, 865, 754, 130, 324, 795, 189], Objective value = 1073.8200000000002
# Generation 33: Best solution = [791, 381, 903, 252, 1010, 824, 784, 194], Objective value = 1133.54
# Generation 34: Best solution = [207, 38, 884, 279, 565, 444, 556, 648], Objective value = 1074.85
# Generation 35: Best solution = [596, 701, 773, 740, 779, 627, 875, 352], Objective value = 1145.94
# Generation 36: Best solution = [731, 804, 329, 141, 727, 455, 1022, 573], Objective value = 1137.09
# Generation 37: Best solution = [867, 215, 773, 824, 926, 17, 467, 886], Objective value = 1025.1
# Generation 38: Best solution = [665, 308, 489, 774, 796, 262, 17, 352], Objective value = 1092.06
# Generation 39: Best solution = [399, 1020, 687, 803, 171, 379, 215, 55], Objective value = 1179.45
# Generation 40: Best solution = [761, 867, 573, 888, 329, 891, 249, 1023], Objective value = 1062.67
# Generation 41: Best solution = [453, 127, 359, 817, 773, 620, 895, 841], Objective value = 1097.01
# Generation 42: Best solution = [924, 270, 402, 576, 419, 981, 162, 593], Objective value = 1058.4300000000003
# Generation 43: Best solution = [744, 424, 975, 482, 599, 859, 465, 538], Objective value = 1142.4900000000002
# Generation 44: Best solution = [884, 562, 430, 1008, 551, 970, 154, 266], Objective value = 1149.4
# Generation 45: Best solution = [786, 685, 279, 452, 480, 781, 358, 638], Objective value = 1172.57
# Generation 46: Best solution = [512, 568, 122, 793, 636, 844, 493, 291], Objective value = 1066.48
# Generation 47: Best solution = [982, 808, 194, 885, 187, 821, 917, 469], Objective value = 1074.9899999999998
# Generation 48: Best solution = [13, 226, 9, 951, 198, 145, 476, 84], Objective value = 1025.5
# Generation 49: Best solution = [259, 485, 560, 358, 424, 357, 426, 704], Objective value = 996.3100000000001
# Generation 50: Best solution = [508, 62, 675, 376, 585, 197, 132, 321], Objective value = 1036.09
# Generation 51: Best solution = [322, 214, 200, 536, 909, 870, 7, 920], Objective value = 1151.3
# Generation 52: Best solution = [404, 472, 651, 0, 910, 680, 18, 567], Objective value = 1012.6899999999999
# Generation 53: Best solution = [837, 638, 745, 62, 985, 699, 622, 163], Objective value = 1105.3799999999999
# Generation 54: Best solution = [791, 1017, 487, 66, 940, 505, 666, 221], Objective value = 1232.9
# Generation 55: Best solution = [615, 822, 806, 95, 544, 22, 233, 323], Objective value = 1192.1
# Generation 56: Best solution = [888, 896, 46, 847, 273, 353, 321, 401], Objective value = 1037.02
# Generation 57: Best solution = [710, 463, 420, 902, 717, 944, 648, 179], Objective value = 986.49
# Generation 58: Best solution = [976, 83, 985, 344, 1018, 792, 171, 384], Objective value = 1061.23
# Generation 59: Best solution = [691, 769, 410, 80, 805, 717, 211, 14], Objective value = 1089.4700000000003
# Generation 60: Best solution = [848, 787, 489, 536, 105, 964, 972, 694], Objective value = 1107.37
# Generation 61: Best solution = [471, 908, 955, 73, 182, 981, 519, 247], Objective value = 1041.27
# Generation 62: Best solution = [264, 339, 303, 786, 55, 349, 60, 810], Objective value = 1110.4599999999998
# Generation 63: Best solution = [604, 162, 298, 527, 725, 383, 413, 932], Objective value = 1042.94
# Generation 64: Best solution = [642, 52, 814, 983, 592, 957, 33, 627], Objective value = 1168.34
# Generation 65: Best solution = [194, 34, 1018, 282, 626, 355, 647, 744], Objective value = 1245.83
# Generation 66: Best solution = [924, 70, 992, 115, 254, 257, 416, 755], Objective value = 1062.29
# Generation 67: Best solution = [652, 952, 286, 899, 224, 462, 799, 459], Objective value = 1133.86
# Generation 68: Best solution = [905, 959, 101, 784, 737, 10, 230, 951], Objective value = 1041.35
# Generation 69: Best solution = [452, 651, 903, 373, 222, 976, 884, 141], Objective value = 1143.99
# Generation 70: Best solution = [561, 927, 708, 865, 124, 568, 299, 169], Objective value = 1120.3600000000001
# Generation 71: Best solution = [806, 475, 254, 366, 756, 978, 284, 556], Objective value = 1162.3799999999999
# Generation 72: Best solution = [969, 99, 633, 140, 134, 702, 294, 768], Objective value = 1206.8200000000002
# Generation 73: Best solution = [194, 19, 855, 837, 727, 603, 160, 695], Objective value = 1070.86
# Generation 74: Best solution = [776, 580, 293, 187, 1006, 283, 500, 948], Objective value = 1109.3000000000002
# Generation 75: Best solution = [211, 470, 661, 1019, 704, 79, 764, 13], Objective value = 1111.0700000000002
# Generation 76: Best solution = [213, 879, 550, 980, 593, 775, 147, 662], Objective value = 1094.1299999999999
# Generation 77: Best solution = [348, 362, 339, 281, 168, 950, 493, 421], Objective value = 1094.47
# Generation 78: Best solution = [709, 466, 612, 675, 577, 767, 1019, 474], Objective value = 1146.72
# Generation 79: Best solution = [348, 338, 1007, 204, 845, 445, 145, 257], Objective value = 1154.84
# Generation 80: Best solution = [472, 209, 107, 849, 269, 548, 890, 708], Objective value = 1070.78
# Generation 81: Best solution = [673, 64, 963, 809, 685, 426, 413, 798], Objective value = 1138.52
# Generation 82: Best solution = [951, 601, 788, 432, 747, 173, 217, 59], Objective value = 1189.68
# Generation 83: Best solution = [536, 796, 885, 795, 985, 242, 355, 646], Objective value = 1216.92
# Generation 84: Best solution = [872, 380, 48, 282, 513, 214, 349, 263], Objective value = 1110.48
# Generation 85: Best solution = [464, 460, 896, 676, 766, 795, 944, 377], Objective value = 1072.47
# Generation 86: Best solution = [568, 630, 1010, 335, 867, 986, 774, 570], Objective value = 1067.5600000000002
# Generation 87: Best solution = [365, 121, 246, 626, 507, 590, 49, 383], Objective value = 1144.02
# Generation 88: Best solution = [225, 685, 300, 501, 466, 100, 360, 665], Objective value = 1197.1999999999998
# Generation 89: Best solution = [824, 922, 828, 796, 499, 195, 770, 983], Objective value = 1104.42
# Generation 90: Best solution = [376, 777, 284, 257, 57, 509, 455, 352], Objective value = 1040.45
# Generation 91: Best solution = [430, 608, 878, 380, 683, 901, 394, 125], Objective value = 1180.4599999999998
# Generation 92: Best solution = [957, 547, 865, 497, 212, 814, 202, 241], Objective value = 1173.26
# Generation 93: Best solution = [17, 406, 214, 466, 32, 599, 546, 794], Objective value = 1126.03
# Generation 94: Best solution = [860, 713, 142, 795, 160, 824, 280, 160], Objective value = 1056.2600000000002
# Generation 95: Best solution = [773, 871, 404, 830, 242, 308, 651, 840], Objective value = 1099.07
# Generation 96: Best solution = [244, 336, 514, 267, 803, 703, 192, 37], Objective value = 1085.54
# Generation 97: Best solution = [373, 269, 176, 530, 122, 999, 194, 94], Objective value = 1056.51
# Generation 98: Best solution = [597, 904, 869, 521, 185, 344, 739, 286], Objective value = 1011.45
# Generation 99: Best solution = [290, 517, 211, 269, 146, 586, 484, 169], Objective value = 1157.1800000000003
# Generation 100: Best solution = [416, 107, 26, 975, 580, 741, 607, 496], Objective value = 1183.58
# Final solution: [416, 107, 26, 975, 580, 741, 607, 496], Objective value: 704.8299999999999
# ################################################
